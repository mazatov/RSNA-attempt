# %% [markdown]
# # Overview
# The notebook aims to get a better feeling for the data and more importantly the distributions of values. We take the labels and combine them with the detailed class info and try and determine what the biggest challenges of the prediction might be.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pydicom
import pandas as pd
from glob import glob
import os
from matplotlib.patches import Rectangle
det_class_path = 'input/stage_1_detailed_class_info.csv'
bbox_path = 'input/stage_1_train_labels.csv'
dicom_dir = 'input/stage_1_train_images/'

# %% [markdown]
# # Detailed Class Info
# Here we show the image-level labels for the scans. The most interesting group here is the `No Lung Opacity / Not Normal` since they are cases that look like opacity but are not. So the first step might be to divide the test images into clear groups and then only perform the bounding box prediction on the suspicious images.

# %%
det_class_df = pd.read_csv(det_class_path)
print(det_class_df.shape[0], 'class infos loaded')
print(det_class_df['patientId'].value_counts().shape[0], 'patient cases')
det_class_df.groupby('class').size().plot.bar()
det_class_df.sample(3)
# Out:
# 28989 class infos loaded
# 25684 patient cases
#                                   patientId                         class
# 5903   4a9e697e-e8e7-4996-9bf8-2d3bb6e31ebd  No Lung Opacity / Not Normal
# 20659  bc8eef60-eaf9-4586-be77-5be336f9b27c  No Lung Opacity / Not Normal
# 28603  fd03d0f4-c4f8-4242-ad20-a69256fd1d93  No Lung Opacity / Not Normal

# %% [markdown]
# # Load the Bounding Box Data
# Here we show the bounding boxes

# %%
bbox_df = pd.read_csv(bbox_path)
print(bbox_df.shape[0], 'boxes loaded')
print(bbox_df['patientId'].value_counts().shape[0], 'patient cases')
bbox_df.sample(3)
# Out:
# 28989 boxes loaded
# 25684 patient cases
#                                   patientId      x      y  width  height  \
# 5376   4668a90c-d352-47d0-a3ac-a54aa8ce053b  523.0  269.0  207.0   222.0
# 26105  e93ef558-f463-4979-879a-c108f0b0a408    NaN    NaN    NaN     NaN
# 20677  bca62fcd-acd1-4ffb-8e1e-fabd4f7c400f  631.0  252.0  355.0   674.0
#
#        Target
# 5376        1
# 26105       0
# 20677       1

# %% [markdown]
# # Combine Boxes and Labels
# Here we bring the labels and the boxes together and now we can focus on how the boxes look on the images

# %%
# we first try a join and see that it doesn't work (we end up with too many boxes)
comb_bbox_df = pd.merge(bbox_df, det_class_df, how='inner', on='patientId')
print(comb_bbox_df.shape[0], 'combined cases')
# Out:
# 35875 combined cases

# %%
comb_bbox_df.head()
# Out:
#                               patientId      x      y  width  height  Target  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
#
#                           class
# 0  No Lung Opacity / Not Normal
# 1  No Lung Opacity / Not Normal
# 2  No Lung Opacity / Not Normal
# 3                        Normal
# 4                  Lung Opacity

# %% [markdown]
# ## Concatenate
# We have to concatenate the two datasets and then we get class and target information on each region

# %%
comb_bbox_df = pd.concat([bbox_df, 
                        det_class_df.drop('patientId',1)], 1)
print(comb_bbox_df.shape[0], 'combined cases')
comb_bbox_df.sample(3)

# %% [markdown]
# # Distribution of Boxes and Labels
# The values below show the number of boxes and the patients that have that number.

# %%
box_df = comb_bbox_df.groupby('patientId').\
    size().\
    reset_index(name='boxes')
comb_box_df = pd.merge(comb_bbox_df, box_df, on='patientId')
box_df.\
    groupby('boxes').\
    size().\
    reset_index(name='patients')
# Out:
#    boxes  patients
# 0      1     22506
# 1      4      3062
# 2      9       105
# 3     16        11

# %% [markdown]
# # How are class and target related?
# I assume that all the `Target=1` values fall in the `Lung Opacity` class, but it doesn't hurt to check.

# %%
comb_bbox_df.groupby(['class', 'Target']).size().reset_index(name='Patient Count')
# Out:
#                           class  Target  Patient Count
# 0                  Lung Opacity       1          15850
# 1  No Lung Opacity / Not Normal       0          11500
# 2                        Normal       0           8525

# %% [markdown]
# # Images
# Now that we have the boxes and labels loaded we can examine a few images.

# %%
image_df = pd.DataFrame({'path': glob(os.path.join(dicom_dir, '*.dcm'))})
image_df['patientId'] = image_df['path'].map(lambda x: os.path.splitext(os.path.basename(x))[0])
print(image_df.shape[0], 'images found')
img_pat_ids = set(image_df['patientId'].values.tolist())
box_pat_ids = set(comb_box_df['patientId'].values.tolist())
# check to make sure there is no funny business
assert img_pat_ids.union(box_pat_ids)==img_pat_ids, "Patient IDs should be the same"
# Out:
# 25684 images found

# %% [markdown]
# # Enrich the image fields
# We have quite a bit of additional data in the DICOM header we can easily extract to help learn more about the patient like their age, view position and gender which can make the model much more precise

# %%
DCM_TAG_LIST = ['PatientAge', 'BodyPartExamined', 'ViewPosition', 'PatientSex']
def get_tags(in_path):
    c_dicom = pydicom.read_file(in_path, stop_before_pixels=True)
    tag_dict = {c_tag: getattr(c_dicom, c_tag, '') 
         for c_tag in DCM_TAG_LIST}
    tag_dict['path'] = in_path
    return pd.Series(tag_dict)
image_meta_df = image_df.apply(lambda x: get_tags(x['path']), 1)
# show the summary
image_meta_df['PatientAge'] = image_meta_df['PatientAge'].map(int)
image_meta_df['PatientAge'].hist()
image_meta_df.drop('path',1).describe(exclude=np.number)
# Out:
#        BodyPartExamined ViewPosition PatientSex
# count             25684        25684      25684
# unique                1            2          2
# top               CHEST           PA          M
# freq              25684        13979      14593

# %%
image_full_df = pd.merge(image_df,
                         image_meta_df,
                         on='path')
image_bbox_df = pd.merge(comb_box_df, 
                         image_full_df, 
                         on='patientId',
                        how='left')
print(image_bbox_df.shape[0], 'image bounding boxes')
image_bbox_df.sample(3)
# Out:
# 35875 image bounding boxes
#                                   patientId   x   y  width  height  Target  \
# 13392  71335a57-2671-4ed6-9a0b-291915031efe NaN NaN    NaN     NaN       0
# 19604  99679f2e-a780-408c-96ab-9547197e3309 NaN NaN    NaN     NaN       0
# 18571  9213dc17-1267-42a4-a71d-546a4d994a4a NaN NaN    NaN     NaN       0
#
#                               class  boxes  \
# 13392                        Normal      1
# 19604  No Lung Opacity / Not Normal      1
# 18571                        Normal      1
#
#                                                     path  PatientAge  \
# 13392  input/stage_1_train_images\71335a57-2671-4ed6-...          62
# 19604  input/stage_1_train_images\99679f2e-a780-408c-...          52
# 18571  input/stage_1_train_images\9213dc17-1267-42a4-...          60
#
#       BodyPartExamined ViewPosition PatientSex
# 13392            CHEST           PA          M
# 19604            CHEST           AP          M
# 18571            CHEST           AP          F

# %% [markdown]
# ## Create Sample Data Set
# We create a sample dataset covering different cases, and number of boxes

# %%
sample_df = image_bbox_df.\
    groupby(['Target','class', 'boxes']).\
    apply(lambda x: x[x['patientId']==x.sample(1)['patientId'].values[0]]).\
    reset_index(drop=True)
sample_df
# Out:
#                                patientId      x      y  width  height  Target  \
# 0   737c7eab-7194-4130-a010-954ea6e321e3    NaN    NaN    NaN     NaN       0
# 1   57e10dd1-4c3e-4fce-98c3-5bd2fd1f965d    NaN    NaN    NaN     NaN       0
# 2   9a4b8ac5-0371-4bc0-a609-32ad46806f7c  586.0  161.0  213.0   166.0       1
# 3   db16297d-c849-43b1-bcd3-1bd4fb2ff37e  606.0  582.0  161.0   168.0       1
# 4   db16297d-c849-43b1-bcd3-1bd4fb2ff37e  606.0  582.0  161.0   168.0       1
# 5   db16297d-c849-43b1-bcd3-1bd4fb2ff37e  296.0  586.0  123.0   100.0       1
# 6   db16297d-c849-43b1-bcd3-1bd4fb2ff37e  296.0  586.0  123.0   100.0       1
# 7   12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  568.0  338.0  229.0   257.0       1
# 8   12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  568.0  338.0  229.0   257.0       1
# 9   12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  568.0  338.0  229.0   257.0       1
# 10  12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  275.0  534.0  169.0   203.0       1
# 11  12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  275.0  534.0  169.0   203.0       1
# 12  12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  275.0  534.0  169.0   203.0       1
# 13  12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  604.0  644.0  225.0   118.0       1
# 14  12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  604.0  644.0  225.0   118.0       1
# 15  12b4c5bc-48cb-4010-9b2e-eeb8b0d5cc8e  604.0  644.0  225.0   118.0       1
# 16  8dc8e54b-5b05-4dac-80b9-fa48878621e2  281.0  163.0  201.0   253.0       1
# 17  8dc8e54b-5b05-4dac-80b9-fa48878621e2  281.0  163.0  201.0   253.0       1
# 18  8dc8e54b-5b05-4dac-80b9-fa48878621e2  281.0  163.0  201.0   253.0       1
# 19  8dc8e54b-5b05-4dac-80b9-fa48878621e2  281.0  163.0  201.0   253.0       1
# 20  8dc8e54b-5b05-4dac-80b9-fa48878621e2  602.0  189.0  245.0   347.0       1
# 21  8dc8e54b-5b05-4dac-80b9-fa48878621e2  602.0  189.0  245.0   347.0       1
# 22  8dc8e54b-5b05-4dac-80b9-fa48878621e2  602.0  189.0  245.0   347.0       1
# 23  8dc8e54b-5b05-4dac-80b9-fa48878621e2  602.0  189.0  245.0   347.0       1
# 24  8dc8e54b-5b05-4dac-80b9-fa48878621e2  688.0  548.0  187.0   181.0       1
# 25  8dc8e54b-5b05-4dac-80b9-fa48878621e2  688.0  548.0  187.0   181.0       1
# 26  8dc8e54b-5b05-4dac-80b9-fa48878621e2  688.0  548.0  187.0   181.0       1
# 27  8dc8e54b-5b05-4dac-80b9-fa48878621e2  688.0  548.0  187.0   181.0       1
# 28  8dc8e54b-5b05-4dac-80b9-fa48878621e2  199.0  492.0  267.0   452.0       1
# 29  8dc8e54b-5b05-4dac-80b9-fa48878621e2  199.0  492.0  267.0   452.0       1
# 30  8dc8e54b-5b05-4dac-80b9-fa48878621e2  199.0  492.0  267.0   452.0       1
# 31  8dc8e54b-5b05-4dac-80b9-fa48878621e2  199.0  492.0  267.0   452.0       1
#
#                            class  boxes  \
# 0   No Lung Opacity / Not Normal      1
# 1                         Normal      1
# 2                   Lung Opacity      1
# 3                   Lung Opacity      4
# 4                   Lung Opacity      4
# 5                   Lung Opacity      4
# 6                   Lung Opacity      4
# 7                   Lung Opacity      9
# 8                   Lung Opacity      9
# 9                   Lung Opacity      9
# 10                  Lung Opacity      9
# 11                  Lung Opacity      9
# 12                  Lung Opacity      9
# 13                  Lung Opacity      9
# 14                  Lung Opacity      9
# 15                  Lung Opacity      9
# 16                  Lung Opacity     16
# 17                  Lung Opacity     16
# 18                  Lung Opacity     16
# 19                  Lung Opacity     16
# 20                  Lung Opacity     16
# 21                  Lung Opacity     16
# 22                  Lung Opacity     16
# 23                  Lung Opacity     16
# 24                  Lung Opacity     16
# 25                  Lung Opacity     16
# 26                  Lung Opacity     16
# 27                  Lung Opacity     16
# 28                  Lung Opacity     16
# 29                  Lung Opacity     16
# 30                  Lung Opacity     16
# 31                  Lung Opacity     16
#
#                                                  path  PatientAge  \
# 0   input/stage_1_train_images\737c7eab-7194-4130-...          26
# 1   input/stage_1_train_images\57e10dd1-4c3e-4fce-...          44
# 2   input/stage_1_train_images\9a4b8ac5-0371-4bc0-...          42
# 3   input/stage_1_train_images\db16297d-c849-43b1-...          28
# 4   input/stage_1_train_images\db16297d-c849-43b1-...          28
# 5   input/stage_1_train_images\db16297d-c849-43b1-...          28
# 6   input/stage_1_train_images\db16297d-c849-43b1-...          28
# 7   input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 8   input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 9   input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 10  input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 11  input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 12  input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 13  input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 14  input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 15  input/stage_1_train_images\12b4c5bc-48cb-4010-...          38
# 16  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 17  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 18  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 19  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 20  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 21  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 22  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 23  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 24  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 25  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 26  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 27  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 28  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 29  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 30  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
# 31  input/stage_1_train_images\8dc8e54b-5b05-4dac-...          76
#
#    BodyPartExamined ViewPosition PatientSex
# 0             CHEST           AP          F
# 1             CHEST           PA          M
# 2             CHEST           PA          M
# 3             CHEST           AP          F
# 4             CHEST           AP          F
# 5             CHEST           AP          F
# 6             CHEST           AP          F
# 7             CHEST           AP          F
# 8             CHEST           AP          F
# 9             CHEST           AP          F
# 10            CHEST           AP          F
# 11            CHEST           AP          F
# 12            CHEST           AP          F
# 13            CHEST           AP          F
# 14            CHEST           AP          F
# 15            CHEST           AP          F
# 16            CHEST           AP          M
# 17            CHEST           AP          M
# 18            CHEST           AP          M
# 19            CHEST           AP          M
# 20            CHEST           AP          M
# 21            CHEST           AP          M
# 22            CHEST           AP          M
# 23            CHEST           AP          M
# 24            CHEST           AP          M
# 25            CHEST           AP          M
# 26            CHEST           AP          M
# 27            CHEST           AP          M
# 28            CHEST           AP          M
# 29            CHEST           AP          M
# 30            CHEST           AP          M
# 31            CHEST           AP          M

# %% [markdown]
# ## Show the position and bounding box
# Here we can see the position (point) and the bounding box for each of the different image types

# %%
fig, m_axs = plt.subplots(2, 3, figsize = (20, 10))
for c_ax, (c_path, c_rows) in zip(m_axs.flatten(),
                    sample_df.groupby(['path'])):
    c_dicom = pydicom.read_file(c_path)
    c_ax.imshow(c_dicom.pixel_array, cmap='bone')
    c_ax.set_title('{class}'.format(**c_rows.iloc[0,:]))
    for i, (_, c_row) in enumerate(c_rows.dropna().iterrows()):
        c_ax.plot(c_row['x'], c_row['y'], 's', label='{class}'.format(**c_row))
        c_ax.add_patch(Rectangle(xy=(c_row['x'], c_row['y']),
                                width=c_row['width'],
                                height=c_row['height'], 
                                 alpha = 0.5))
        if i==0: c_ax.legend()

# %% [markdown]
# # Bounding Box Distribution
# Here we just look at the bounding box distribution to get a better idea how this looks over the whole dataset

# %%
pos_bbox = image_bbox_df.query('Target==1')
pos_bbox.plot.scatter(x='x', y='y')

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (10, 10))
ax1.set_xlim(0, 1024)
ax1.set_ylim(0, 1024)
for _, c_row in pos_bbox.sample(1000).iterrows():
    ax1.add_patch(Rectangle(xy=(c_row['x'], c_row['y']),
                 width=c_row['width'],
                 height=c_row['height'],
                           alpha=5e-3))

# %% [markdown]
# # Show the boxes as segmentation
# By showing them as segmentations we can get a better probability map for where the opacity regions are most likely to occur

# %%
# Show the boxes themselves
X_STEPS, Y_STEPS = 1024, 1024
xx, yy = np.meshgrid(np.linspace(0, 1024, X_STEPS),
           np.linspace(0, 1024, Y_STEPS), 
           indexing='xy')
prob_image = np.zeros_like(xx)
for _, c_row in pos_bbox.sample(5000).iterrows():
    c_mask = (xx>=c_row['x']) & (xx<=(c_row['x']+c_row['width']))
    c_mask &= (yy>=c_row['y']) & (yy<=c_row['y']+c_row['height'])
    prob_image += c_mask
fig, ax1 = plt.subplots(1, 1, figsize = (10, 10))
ax1.imshow(prob_image, cmap='hot')

# %% [markdown]
# # Overlay the Probability on a few images
# Does the probability we calculate seem to make sense? or have we flipped something somewhere?

# %%
fig, m_axs = plt.subplots(2, 3, figsize = (20, 10))
for c_ax, (c_path, c_rows) in zip(m_axs.flatten(),
                    sample_df.groupby(['path'])):
    c_img_arr = pydicom.read_file(c_path).pixel_array
    # overlay
    c_img = plt.cm.gray(c_img_arr)
    c_img += 0.25*plt.cm.hot(prob_image/prob_image.max())
    c_img = np.clip(c_img, 0, 1)
    c_ax.imshow(c_img)
    
    c_ax.set_title('{class}'.format(**c_rows.iloc[0,:]))
    for i, (_, c_row) in enumerate(c_rows.dropna().iterrows()):
        c_ax.plot(c_row['x'], c_row['y'], 's', label='{class}'.format(**c_row))
        c_ax.add_patch(Rectangle(xy=(c_row['x'], c_row['y']),
                                width=c_row['width'],
                                height=c_row['height'], 
                                 alpha = 0.5,
                                fill=False))
        if i==0: c_ax.legend()
fig.savefig('overview.png', figdpi = 600)

# %% [markdown]
# ### Save the preprocessed results
# We can use the preprocessed results with the appropriate DICOM tags to make model training step easier

# %%
image_bbox_df.to_csv('image_bbox_full.csv', index=False)
